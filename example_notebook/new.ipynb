# %% [markdown]
# ## Import Packages

# %%
import edaSQL
import pandas as pd

# %% [markdown]
# <br>

# %% [markdown]
# # 1. Connect to the DataBase

# %%
edasql = edaSQL.SQL(printAll=True)
edasql.connectToDataBase(server='LAPTOP-Q7G2RLEF', database='edaSQL', user='tamil', password='tt')
# Out:
# <img src="https://raw.githubusercontent.com/selva221724/edaSQL/main/readme_src/sql_logo_smaller.png" width="50%" height="50%">
# ========== Connected to DataBase Successfully ===========
# Server:  LAPTOP-Q7G2RLEF
# DataBase:  edaSQL
# User :  tamil
# Password :  tt

# %% [markdown]
# <br>

# %% [markdown]
# # 2. Query Data

# %%
data = pd.read_sql("select  * from INX", edasql.dbConnection)

# %%
display(data.head())
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency DistanceFromHome EmpEducationLevel  \
# 0  Sales Executive           Travel_Rarely               10                 3
# 1  Sales Executive           Travel_Rarely               14                 4
# 2  Sales Executive       Travel_Frequently                5                 4
# 3          Manager           Travel_Rarely               10                 4
# 4  Sales Executive           Travel_Rarely               16                 4
#
#    ... Location  TotalWorkExperienceInYears TrainingTimesLastYear  \
# 0  ...    India                          10                     2
# 1  ...    India                          20                     2
# 2  ...    India                          20                     2
# 3  ...    India                          23                     2
# 4  ...    India                          10                     1
#
#   EmpWorkLifeBalance ExperienceYearsAtThisCompany  \
# 0                  2                           10
# 1                  3                            7
# 2                  3                           18
# 3                  2                           21
# 4                  3                            2
#
#   ExperienceYearsInCurrentRole YearsSinceLastPromotion YearsWithCurrManager  \
# 0                            7                       0                    8
# 1                            7                       1                    7
# 2                           13                       1                   12
# 3                            6                      12                    6
# 4                            2                       2                    2
#
#    Attrition PerformanceRating
# 0          0                 3
# 1          0                 3
# 2          0                 4
# 3          0                 3
# 4          0                 3
#
# [5 rows x 30 columns]

# %% [markdown]
# <br>

# %% [markdown]
# # 3. Data Overview

# %%
ins =  edaSQL.EDA(dataFrame=data,HTMLDisplay=True)

# %%
dataInsights =ins.dataInsights()
# print(dataInsights)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <style>
# table {
#   border-collapse: collapse;
#
# }
#
# td, th {
#   border: 1px solid #dddddd;
#   text-align: left;
#   padding: 18px;
# }
#
# tr:nth-child(even) {
#   background-color: #dddddd;
# }
# </style>
# </head>
# <body>
#
# <h1 style=font-size:15px>Dataset Overview</h1><table><tr><th>Number of Columns :</th><td> 30</td></tr><tr><th>Number of Rows :</th><td> 1200</td></tr><tr><th>Overall Missing cells :</th><td> 617</td></tr><tr><th>Overall Missing cells (%) :</th><td> 1.74</td></tr><tr><th>Duplicate rows :</th><td> 0</td></tr><tr><th>Duplicate rows (%) :</th><td> 0.0</td></tr></table></body></html><br><!DOCTYPE html>
# <html>
# <head>
# <style>
# table {
#   border-collapse: collapse;
#
# }
#
# td, th {
#   border: 1px solid #dddddd;
#   text-align: left;
#   padding: 18px;
# }
#
# tr:nth-child(even) {
#   background-color: #dddddd;
# }
# </style>
# </head>
# <body>
#
# <h1 style=font-size:15px>Types of Columns</h1><table><tr><th>Numeric :</th><td> 5</td></tr><tr><th>Categorical :</th><td> 25</td></tr><tr><th>Date and Time :</th><td> 0</td></tr></table></body></html><br>

# %%
deepInsights = ins.deepInsights()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <style>
# table {
#
# }
#
# td,th {
#   border: 1px solid #dddddd;
#   text-align: centre;
#   padding: 8px
# }
#
# tr:nth-child(even) {
#   background-color: #dddddd;
# }
# </style>
# </head>
# <body>
#
# <h1 style=font-size:15px>Columns with Constant Values</h1><table><tr><th>Column</th><th>Value</th><tr><td>Location</td><td> India</td></tr></table></body></html><br><!DOCTYPE html>
# <html>
# <head>
# <style>
# table {
#
# }
#
# td,th {
#   border: 1px solid #dddddd;
#   text-align: centre;
#   padding: 8px
# }
#
# tr:nth-child(even) {
#   background-color: #dddddd;
# }
# </style>
# </head>
# <body>
#
# <h1 style=font-size:15px>Columns with High Cardinality</h1><table><tr><th>Column</th><th>No of Unique Values</th><tr><td>Notes</td><td> 707</td></tr></table></body></html><br><!DOCTYPE html>
# <html>
# <head>
# <style>
# table {
#
# }
#
# td,th {
#   border: 1px solid #dddddd;
#   text-align: centre;
#   padding: 8px
# }
#
# tr:nth-child(even) {
#   background-color: #dddddd;
# }
# </style>
# </head>
# <body>
#
# <h1 style=font-size:15px>Columns with  with Unique ID's</h1><table><tr><td > EmpNumber</td></tr></table></body></html><br><!DOCTYPE html>
# <html>
# <head>
# <style>
# table {
#
# }
#
# td,th {
#   border: 1px solid #dddddd;
#   text-align: centre;
#   padding: 8px
# }
#
# tr:nth-child(even) {
#   background-color: #dddddd;
# }
# </style>
# </head>
# <body>
#
# <h1 style=font-size:15px>Columns with Missing Values Percentage</h1><table><tr><th>Column</th><th>Percentage</th><tr><td>Notes</td><td> 36.58</td></tr><tr><td>EmpJobLevel</td><td> 2.67</td></tr><tr><td>EmpJobSatisfaction</td><td> 2.58</td></tr><tr><td>TotalWorkExperienceInYears</td><td> 1.92</td></tr><tr><td>EmpRelationshipSatisfaction</td><td> 1.58</td></tr><tr><td>ExperienceYearsAtThisCompany</td><td> 1.5</td></tr><tr><td>YearsWithCurrManager</td><td> 1.42</td></tr><tr><td>EmpLastSalaryHikePercent</td><td> 1.08</td></tr><tr><td>YearsSinceLastPromotion</td><td> 0.92</td></tr><tr><td>EmpJobInvolvement</td><td> 0.75</td></tr><tr><td>TrainingTimesLastYear</td><td> 0.42</td></tr></table></body></html><br><!DOCTYPE html>
# <html>
# <head>
# <style>
# table {
#
# }
#
# td,th {
#   border: 1px solid #dddddd;
#   text-align: centre;
#   padding: 8px
# }
#
# tr:nth-child(even) {
#   background-color: #dddddd;
# }
# </style>
# </head>
# <body>
#
# <h1 style=font-size:15px>Columns with Binary Values</h1><table><tr><td > Attrition</td></tr></table></body></html><br>

# %% [markdown]
# <br>

# %% [markdown]
# # 4.Correlation

# %%
eda = edaSQL.EDA(dataFrame=data)

# %% [markdown]
# ## 4.1 Pearson Correlation

# %%
eda.pearsonCorrelation()

# %% [markdown]
# ## 4.2 Spearman Correlation

# %%
eda.spearmanCorrelation()

# %% [markdown]
# ## 4.3 Kendall Correlation

# %%
eda.kendallCorrelation()

# %% [markdown]
# <br>

# %% [markdown]
# # 5. Missing Values

# %% [markdown]
# ## 5.1 Matrix Plot

# %%
eda.missingValuesPlot(plot ='matrix')

# %% [markdown]
# ## 5.2 Count Bar Plot

# %%
eda.missingValuesPlot(plot ='bar')

# %% [markdown]
# ## 5.3 Heatmap Plot

# %%
eda.missingValuesPlot(plot ='heatmap')

# %% [markdown]
# ## 5.4 Dendrogram Plot

# %%
eda.missingValuesPlot(plot ='dendrogram')

# %% [markdown]
# <br>

# %% [markdown]
# # 6. Outliers

# %% [markdown]
# ## 6.1 Visualization

# %% [markdown]
# ## 6.1.1 Box Plot

# %%
eda.outliersVisualization(plot = 'box')

# %% [markdown]
# ## 6.1.2 Scatter Plot

# %%
eda.outliersVisualization(plot = 'scatter')

# %% [markdown]
# ## 6.2 Get Outliers

# %%
outliers = eda.getOutliers()
# Out:
# <h1 style="background-color:powderblue;font-size:16px;">Age</h1>
#       Age
# 4      60
# 105    58
# 117    58
# 128    19
# 159    18
# 173    59
# 186    59
# 242    18
# 266    19
# 294    19
# 313    59
# 331    58
# 351    58
# 357    18
# 388    58
# 504    18
# 548    60
# 615    58
# 623    58
# 624    18
# 678    58
# 768    59
# 817    59
# 845    58
# 867    58
# 868    19
# 885    19
# 891    58
# 904    19
# 910    19
# 957    59
# 1011   18
# 1016   18
# 1104   60
# 1114   19
# 1144   18
# <h1 style="background-color:powderblue;font-size:16px;">EmpHourlyRate</h1>
#       EmpHourlyRate
# 116             100
# 141             100
# 219              30
# 249             100
# 277              30
# 407             100
# 432              30
# 444             100
# 568              30
# 608             100
# 701              30
# 748             100
# 750             100
# 760              30
# 811              30
# 831              30
# 850             100
# 856              30
# 869             100
# 904             100
# 905              30
# 907              30
# 965             100
# 980             100
# 992             100
# 1045             30
# 1101             30
# <h1 style="background-color:powderblue;font-size:16px;">EmpLastSalaryHikePercent</h1>
#       EmpLastSalaryHikePercent
# 13                        11.0
# 15                        11.0
# 17                        11.0
# 22                        11.0
# 25                        11.0
# ...                        ...
# 1176                      11.0
# 1187                      11.0
# 1188                      11.0
# 1189                      11.0
# 1197                      11.0
#
# [192 rows x 1 columns]
# <h1 style="background-color:powderblue;font-size:16px;">Attrition</h1>
#       Attrition
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 1195          0
# 1196          0
# 1197          0
# 1198          0
# 1199          1
#
# [1200 rows x 1 columns]
# <h1 style="background-color:powderblue;font-size:16px;">PerformanceRating</h1>
#       PerformanceRating
# 2                     4
# 5                     4
# 12                    4
# 18                    4
# 25                    4
# ...                 ...
# 1190                  4
# 1191                  4
# 1192                  4
# 1195                  4
# 1199                  2
#
# [326 rows x 1 columns]
